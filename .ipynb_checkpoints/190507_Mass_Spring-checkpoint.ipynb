# %%
using DifferentialEquations, PyPlot, LinearAlgebra

k, b, M = 1.2, 0.3, 2.0
A = [0 1;
-k/M -b/M]

initX = [8.,0.0]
tEnd = 50.0;
tRange = 0:0.1:tEnd

manualSol = [exp(A*t)*initX for t in tRange]

linearRHS(x,Amat,t) = Amat*x
prob = ODEProblem(linearRHS, initX, (0,tEnd), A)
sol = solve(prob)

figure(figsize=(10,5))
subplot(121)
xlim(-7,9);ylim(-9,7)
plot(first.(manualSol),last.(manualSol),"b", label="Manual trajectory")
plot(first.(sol.u),last.(sol.u),"r.", label="DiffEq package")
plot(initX[1],initX[2],"k.",ms="15",label="Initial state")
xlabel("Displacement"); ylabel("Velocity"); legend(loc="upper right")

subplot(122)
plot(tRange,first.(manualSol),"b", label="Manual trajectory")
plot(sol.t,first.(sol.u),"r.", label="DiffEq package")
plot(0,initX[1],"k.",ms="15",label="Initial state");
xlabel("Time"); ylabel("Displacement"); legend(loc="upper right")
# Out:
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall C:\Users\DSEP0001\.julia\packages\PyCall\BD546\src\PyCall.jl:711
# ┌ Info: Running `conda install -y matplotlib` in root environment
# └ @ Conda C:\Users\DSEP0001\.julia\packages\Conda\sNGum\src\Conda.jl:128
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DSEP0001\.julia\conda\3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     kiwisolver-1.3.1           |   py39h2e07f2f_1          58 KB  conda-forge
#     lz4-c-1.9.3                |       h8ffe710_1         135 KB  conda-forge
#     matplotlib-3.4.3           |   py39hcbf5309_0           8 KB  conda-forge
#     matplotlib-base-3.4.3      |   py39h581301d_0         7.2 MB  conda-forge
#     pillow-8.3.1               |   py39h916092e_0         781 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   freetype           conda-forge/win-64::freetype-2.10.4-h546665d_1
#   jbig               conda-forge/win-64::jbig-2.1-h8d14728_2003
#   kiwisolver         conda-forge/win-64::kiwisolver-1.3.1-py39h2e07f2f_1
#   lcms2              conda-forge/win-64::lcms2-2.12-h2a16943_0
#   lerc               conda-forge/win-64::lerc-2.2.1-h0e60522_0
#   libdeflate         conda-forge/win-64::libdeflate-1.7-h8ffe710_5
#   libtiff            conda-forge/win-64::libtiff-4.3.0-h0c97f57_1
#   lz4-c              conda-forge/win-64::lz4-c-1.9.3-h8ffe710_1
#   matplotlib         conda-forge/win-64::matplotlib-3.4.3-py39hcbf5309_0
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.4.3-py39h581301d_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openjpeg           conda-forge/win-64::openjpeg-2.4.0-hb211442_1
#   pillow             conda-forge/win-64::pillow-8.3.1-py39h916092e_0
#   tk                 conda-forge/win-64::tk-8.6.10-h8ffe710_1
#   xz                 conda-forge/win-64::xz-5.2.5-h62dcd97_1
#   zstd               conda-forge/win-64::zstd-1.5.0-h6255e5f_0
#
#
#
# Downloading and Extracting Packages
# pillow-8.3.1         | 781 KB    | ########## | 100%
# lz4-c-1.9.3          | 135 KB    | ########## | 100%
# kiwisolver-1.3.1     | 58 KB     | ########## | 100%
# matplotlib-base-3.4. | 7.2 MB    | ########## | 100%
# matplotlib-3.4.3     | 8 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000004C63E6D0>
